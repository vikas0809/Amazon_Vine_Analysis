# %%
import pandas as pd

# %%
df=pd.read_csv("Data/vine_table.csv")

# %%
df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0         REAKC26P07MDN          5.0            0.0          0.0    N
# 1        R3NU7OMZ4HQIEG          2.0            0.0          1.0    N
# 2        R14QJW3XF8QO1P          5.0            0.0          0.0    N
# 3        R2HB7AX0394ZGY          5.0            0.0          0.0    N
# 4         RGKMPDQGSAHR3          5.0            0.0          0.0    N
# ...                 ...          ...            ...          ...  ...
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0    N
# 2643615  R13RP6H1OP0BFS          5.0            3.0          3.0    N
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0    N
# 2643617   R30D2N6TX0OFS          3.0            7.0          7.0    N
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# ...

# %%
step1_filter_df=df.loc[df["total_votes"]>=20]
step1_filter_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0    N
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0    N
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0    N
# 267       RVTYWID2TPMMY          2.0           35.0         42.0    N
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0    N
# ...                 ...          ...            ...          ...  ...
# 2643586   RDDVO19Y8YH01          1.0           12.0         56.0    N
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0    N
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0    N
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0    N
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0    N
#
#         verified_purchase
# 128                     Y
# 161                     Y
# 256                     Y
# ...

# %%
step1_filter_df["vote_ratio"]=round(step1_filter_df["helpful_votes"]/step1_filter_df["total_votes"]*100,2)
# Out:
# /var/folders/bv/vmvp5g1927n_rwgrdcs5g1dc0000gn/T/ipykernel_84902/1962039750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   step1_filter_df["vote_ratio"]=round(step1_filter_df["helpful_votes"]/step1_filter_df["total_votes"]*100,2)

# %%
step1_filter_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0    N
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0    N
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0    N
# 267       RVTYWID2TPMMY          2.0           35.0         42.0    N
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0    N
# ...                 ...          ...            ...          ...  ...
# 2643586   RDDVO19Y8YH01          1.0           12.0         56.0    N
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0    N
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0    N
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0    N
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0    N
#
#         verified_purchase  vote_ratio
# 128                     Y       87.10
# 161                     Y      100.00
# ...

# %%
step2_filter_df=step1_filter_df.loc[step1_filter_df["vote_ratio"]>=50.00]
step2_filter_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0    N
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0    N
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0    N
# 267       RVTYWID2TPMMY          2.0           35.0         42.0    N
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0    N
# ...                 ...          ...            ...          ...  ...
# 2643577  R37NBT4U1EL04K          5.0           47.0         61.0    N
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0    N
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0    N
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0    N
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0    N
#
#         verified_purchase  vote_ratio
# 128                     Y       87.10
# 161                     Y      100.00
# ...

# %%
total_five_star_reviews_df=step2_filter_df.loc[step2_filter_df["star_rating"]==5.0]
total_five_star_reviews=len(total_five_star_reviews_df)
total_five_star_reviews
# Out:
# 20677

# %%
paid_reviews_df=step2_filter_df.loc[step2_filter_df["vine"]=="Y"]
paid_reviews_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 8547     R3A71VR1JZD8WF          2.0           27.0         30.0    Y
# 10246    R16OMUJIGI18JZ          5.0           72.0         72.0    Y
# 25168    R3TS8ZP2FHQ9XR          5.0           39.0         42.0    Y
# 46422    R2MHP919VZN7DI          5.0           29.0         30.0    Y
# 66446     RD2BCTVS59A5L          2.0           20.0         20.0    Y
# ...                 ...          ...            ...          ...  ...
# 2596353   RV5OQXGCYHSC6          5.0           24.0         28.0    Y
# 2596519  R2XLAQL0E2UPWQ          4.0           33.0         34.0    Y
# 2597336  R2UJFVH97OJORD          3.0          106.0        117.0    Y
# 2597830   RJXG84I331N9T          3.0          146.0        154.0    Y
# 2598196   RNGRV0353CDWX          4.0          109.0        115.0    Y
#
#         verified_purchase  vote_ratio
# 8547                    N       90.00
# 10246                   N      100.00
# ...

# %%
paid_five_star_reviews_df=paid_reviews_df.loc[paid_reviews_df["star_rating"]==5.0]
paid_five_star_reviews=len(paid_five_star_reviews_df)
paid_five_star_reviews
# Out:
# 65

# %%
paid_reviews_ratio=round(paid_five_star_reviews/len(paid_reviews_df)*100,2)
paid_reviews_ratio
# Out:
# 38.24

# %%
unpaid_reviews_df=step2_filter_df.loc[step2_filter_df["vine"]=="N"]
unpaid_reviews_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 128      R21KC552Y6HL8X          1.0           27.0         31.0    N
# 161       RX9WC9FTIR1XR          5.0           25.0         25.0    N
# 256       RGDCOU1KBHMNG          3.0           29.0         31.0    N
# 267       RVTYWID2TPMMY          2.0           35.0         42.0    N
# 719      R2CMPZ5VESGRLY          4.0           27.0         28.0    N
# ...                 ...          ...            ...          ...  ...
# 2643577  R37NBT4U1EL04K          5.0           47.0         61.0    N
# 2643591   RU2X9GTDZ00IM          5.0           58.0         59.0    N
# 2643614   R40AVFLMGSX5Q          1.0           32.0         34.0    N
# 2643616  R34ITLN8LBTFZN          3.0           48.0         56.0    N
# 2643618  R2MAGOAOXPFMF1          2.0           17.0         20.0    N
#
#         verified_purchase  vote_ratio
# 128                     Y       87.10
# 161                     Y      100.00
# ...

# %%
unpaid_five_star_reviews_df=unpaid_reviews_df.loc[unpaid_reviews_df["star_rating"]==5.0]
unpaid_five_star_reviews=len(unpaid_five_star_reviews_df)
unpaid_five_star_reviews
# Out:
# 20612

# %%
unpaid_reviews_ratio=round(unpaid_five_star_reviews/len(unpaid_reviews_df)*100,2)
unpaid_reviews_ratio
# Out:
# 54.47
